# %% [markdown]
# <a href="https://colab.research.google.com/github/Julieth-Garzon07/Talento-Tech/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica 1 de Talento Tech: Incluye importar un Dataset

# %%
# Paso 1: Debo tener el archivo en una carpeta
# Paso 2: Debo establecer un conexion con la carpeta
# Paso 3: Ejecutar las celdas de la conexion y revizar que esta ok

# %% [markdown]
# # Suma de Variables

# %%
#variable o input
val1 = 15
val2 = 12

#proceso
Suma = val1 + val2

#output - salida
print(Suma)
# Out:
# 27

# %% [markdown]
# # Ingreso de nuevos Datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Ventas (2).xlsx'
# Establece la coneccion con la fuente y on el Dataset de prueba

# %%
import pandas as pd
# Importamos la libreria para la manipulacion de datos llamada pandas

# %%
df = pd.read_excel(path)
# Creamos un Dataframe de pandas con los datos suministrados

# %% [markdown]
# # Creacion y lectura de Dataframe
#
#
# *   pd.Dataframe(Data): Crea un Dataframe a partir de Datos
# *   pd.read_csv(**archivo**.csv): Lee un archivo CSV y crea un Dataframe
# *   pd.read_excel(archivo.xlsx): Lee un archivo de excel y crea un Dataframe

# %% [markdown]
# #Visualizacion y Exploracion de Datos
#
# *   df.head():Muetra las primras filas del DataFrame.
# *   df.tail():Muestra ls ultimas filas del DataFrame.
# *   df.info():Muestra informacion sobre el DataFrame, incluyendo tipo de datos y valores no nulos.
# *   df.describe():Proporciona estadisticas descriptivas para columnas numericas.
# *   df.shape: Devuelve una tupla con la cantidad de filas y columnas del DataFrame.
# *   df.columns:Devuelve una lista con los nombres de las columnas del DataFrame.

# %%
df.tail()
# Out:
#    Region      Producto Vendedor  Ventas
# 13  Oeste    Accesorios     Sara    5442
# 14  Oeste  Dispositivos    Kevin   10711
# 15  Oeste  Dispositivos     Sara    8780
# 16  Oeste      Sistemas    Kevin   32855
# 17  Oeste      Sistemas     Sara   23151

# %%
df.head(20)
# Out:
#      Region      Producto Vendedor  Ventas
# 0   Central    Accesorios    David    8287
# 1   Central    Accesorios    Karen    6909
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 6      Este    Accesorios      Ana    9323
# 7      Este    Accesorios    Lucas    7667
# 8      Este  Dispositivos      Ana   10348
# 9      Este  Dispositivos    Lucas    9312
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 14    Oeste  Dispositivos    Kevin   10711
# 15    Oeste  Dispositivos     Sara    8780
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151

# %%
df.info('Region')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    18 non-null     object
#  1   Producto  18 non-null     object
#  2   Vendedor  18 non-null     object
#  3   Ventas    18 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 704.0+ bytes

# %%
df.describe()
# Out:
#              Ventas
# count     18.000000
# mean   13307.388889
# std     8153.055776
# min     4744.000000
# 25%     8410.250000
# 50%    10529.500000
# 75%    13491.750000
# max    32855.000000

# %%
#Ejercicio 1: Mostrar las primeras filas del DataFrame
print("Ejercicio 1: Mostrar las primeras filas del DataFrame")
print(df.head(5))
#print("\n")
# Out:
# Ejercicio 1: Mostrar las primeras filas del DataFrame
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %%
#Ejercicio 2: Calcular el total de ventas por region
print("Ejercicio 2: Calcular el total de ventas por region")
ventas_por_region = df.groupby('Region')['Ventas'].sum()
print(ventas_por_region)
print("\n")
print(df.head(10))
# Out:
# Ejercicio 2: Calcular el total de ventas por region
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
#
#
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098
# 5  Central      Sistemas    Karen   30633
# 6     Este    Accesorios      Ana    9323
# 7     Este    Accesorios    Lucas    7667
# 8     Este  Dispositivos      Ana   10348
# 9     Este  Dispositivos    Lucas    9312

# %%
#Ejercicio 3:Filtrar el DataFrame para mostrar solo las ventas realizadas por David
print("Ejercicio 3: Filtrar el DataFrame para mostrar solo las ventas por David")
ventas_david = df[df['Vendedor'] == 'David']
print(ventas_david)
print("\n")
# Out:
# Ejercicio 3: Filtrar el DataFrame para mostrar solo las ventas por David
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 2  Central  Dispositivos    David   11420
# 4  Central      Sistemas    David   20098

# %%
#Ejercicio 4: Calcular el promedio de ventas por region
print("Ejercicio 4: Calcular el promedio de ventas por region")
ventas_por_producto = df.groupby('Region')['Ventas'].mean()
print(ventas_por_producto)
print("\n")
# Out:
# Ejercicio 4: Calcular el promedio de ventas por region
# Region
# Central    15049.166667
# Este       10592.500000
# Oeste      14280.500000
# Name: Ventas, dtype: float64

# %%
#Ejercicio 5: Ordenar el DataFrame por ventas en orden descendente
print("Ejercicio 5: Ordenar el DataFrame por ventas en orden descendentes")
df_ordenado = df.sort_values(by='Ventas', ascending=False)
print(df_ordenado)
# Out:
# Ejercicio 5: Ordenar el DataFrame por ventas en orden descendentes
#      Region      Producto Vendedor  Ventas
# 16    Oeste      Sistemas    Kevin   32855
# 5   Central      Sistemas    Karen   30633
# 17    Oeste      Sistemas     Sara   23151
# 4   Central      Sistemas    David   20098
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 3   Central  Dispositivos    Karen   12948
# 2   Central  Dispositivos    David   11420
# 14    Oeste  Dispositivos    Kevin   10711
# 8      Este  Dispositivos      Ana   10348
# 6      Este    Accesorios      Ana    9323
# 9      Este  Dispositivos    Lucas    9312
# 15    Oeste  Dispositivos     Sara    8780
# 0   Central    Accesorios    David    8287
# 7      Este    Accesorios    Lucas    7667
# 1   Central    Accesorios    Karen    6909
# 13    Oeste    Accesorios     Sara    5442
# 12    Oeste    Accesorios    Kevin    4744

# %% [markdown]
# # Manipulacion de Datos:
#
# *   Filtra las filas donde las ventas sean mayores a 10000.
# *   Ordena el DataFrame por la columna "Ventas" en orden descendentes.
# *   Elimina la columna "Vendedor".

# %%
# Ejercicio 6: Filtrar las filas con ventas mayores a 10000
print("Ejercicio 6: Filtrar las filas con ventas mayores a 10000")
df_filtrado = df[df['Ventas'] > 10000]
print(df_filtrado)
print("\n")
# Out:
# Ejercicio 6: Filtrar las filas con ventas mayores a 10000
#      Region      Producto Vendedor  Ventas
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 8      Este  Dispositivos      Ana   10348
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 14    Oeste  Dispositivos    Kevin   10711
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151
